# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (4.48.1)
# Requirement already satisfied: filelock in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\athar\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# %%
topic = input("Enter the topic: ")

# Tokenize the input text
input_ids = tokenizer.encode(topic, return_tensors='pt')

# Create an attention mask (ignoring padding tokens)
attention_mask = input_ids.ne(tokenizer.eos_token_id).long()

# Generate text using the GPT-2 model
output = model.generate(input_ids,
                        attention_mask=attention_mask,
                        max_length=200,
                        temperature=1.0,
                        no_repeat_ngram_size=2,
                        pad_token_id=tokenizer.eos_token_id)

# Decode and print the generated text
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text.strip())
# Out:
# Artificial Intelligence (AI) is a new field of research that has been gaining momentum in recent years. The field is now being explored in a number of different ways, including artificial intelligence, artificial neural networks, and artificial language.
#
# The first AI research project was the AI-based artificial brain project at the University of California, Berkeley. In the early 1990s, the project's director, Dr. David S. Karp, was hired by the National Science Foundation to conduct research on the development of artificial brains. He was also the first to use the term "AI" to describe a group of researchers who were working on a project that was not yet ready for publication. This project, called the "Deep Learning Project," was funded by DARPA and the Department of Defense. It was a collaboration between the two agencies that led to the creation of the Deep Learning project. Deep learning is the process by which computers learn to recognize and respond to information. A computer learns to respond by learning
